# %%
---
layout: post
title: Project Supowerpower
categories: ['Kernels']
permalink: /kernels/projectsupowerpower
breadcrumb: True
Author: Akshara Shankar
---

# %% [markdown]
# ## What is the Supowerpower of our project?
# The super power of our project is showing people how to use AI as a study tool and use it purposefully.

# %% [markdown]
# ## Our project Using AI:
# <img width="500" height="341" alt="Image" src="https://github.com/user-attachments/assets/261971e6-5aa6-4318-b0e2-07de19463fc8" />

# %% [markdown]
# <img width="367" height="667" alt="Image" src="https://github.com/user-attachments/assets/34aa6c84-1408-493f-97b7-cfbdcd20f5e9" />

# %% [markdown]
# <img width="677" height="441" alt="Image" src="https://github.com/user-attachments/assets/d7c22074-85f3-446a-8c71-5c00b4bf969b" />
